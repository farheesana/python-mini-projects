# %% [markdown]
# <a href="https://colab.research.google.com/github/farheesana/python-mini-projects/blob/main/Temperature_Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
#       TEMPERATURE CONVERTER
# ==========================================

print("================================")
print("       TEMPERATURE CONVERTER")
print("================================")

print("1. Celsius to Fahrenheit")
print("2. Fahrenheit to Celsius")

choice = int(input("Enter your choice: "))

if choice == 1:

    celsius = float(input("Enter temperature in Celsius: "))

    fahrenheit = (celsius * 9/5) + 32

    print("Temperature in Fahrenheit:", fahrenheit)

elif choice == 2:

    fahrenheit = float(input("Enter temperature in Fahrenheit: "))

    celsius = (fahrenheit - 32) * 5/9

    print("Temperature in Celsius:", celsius)

else:

    print("Invalid choice!")
# Out:
# ...
#        TEMPERATURE CONVERTER
# ...
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# Enter your choice: 2
# Enter temperature in Fahrenheit: 54
# Temperature in Celsius: 12.222222222222221

# %% [markdown]
# # Temperature Converter
#
# ## Objective
#
# To develop a Python program that converts temperature
# between Celsius and Fahrenheit.
#
# ## Features
#
# 1. Celsius to Fahrenheit conversion
# 2. Fahrenheit to Celsius conversion
# 3. User-friendly menu
# 4. Invalid choice handling
#
# ## Formula
#
# Fahrenheit = (Celsius × 9/5) + 32
#
# Celsius = (Fahrenheit - 32) × 5/9
#
# ## Concepts Used
#
# - Variables
# - Input and output
# - Type conversion
# - Arithmetic operators
# - if-elif-else
